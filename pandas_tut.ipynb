# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\18328\\Anaconda3\\lib\\site-packages\\pandas\\__init__.py'>

# %%
df = pd.read_csv('Dataset/data.csv')

# %%
df1 = pd.read_csv('Dataset/data.csv')

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df.iloc[[0,1],2] #searching by location
# Out:
# 9     Yes
# 32    Yes
# Name: Hobbyist, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df.loc[0:678,'Hobbyist':'Gender']
# Out:
#     Hobbyist   Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 0        Yes   NaN         13  Monthly        NaN            NaN
# 1         No   NaN         19      NaN        NaN            NaN
# 2        Yes   NaN         15      NaN        NaN            NaN
# 3        Yes  25.0         18      NaN        NaN            NaN
# 4        Yes  31.0         16      NaN        NaN            NaN
# 5         No   NaN         14      NaN        NaN            NaN
# 6        Yes   NaN         18  Monthly        NaN            NaN
# 7        Yes  36.0         12   Yearly   116000.0       116000.0
# 8         No  30.0         20      NaN        NaN            NaN
# 9        Yes  22.0         14   Yearly    25000.0        32315.0
# 10       Yes  23.0         13   Yearly    31000.0        40070.0
# 11        No  49.0         42  Monthly     1100.0        14268.0
# 12       Yes  53.0         14  Monthly     3000.0        38916.0
# ...

# %%
df.set_index('Respondent' , inplace = True)

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 6                              I am a developer by profession       No   NaN
# 7                              I am a developer by profession      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 9                              I am a developer by profession       No  30.0
# 10                             I am a developer by profession      Yes  22.0
# 11                             I am a developer by profession      Yes  23.0
# ...

# %%
df.loc[3, 'Age']
# Out:
# nan

# %%
df.reset_index()
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# 5               6                     I am a developer by profession       No
# 6               7                     I am a developer by profession      Yes
# 7               8                     I am a developer by profession      Yes
# 8               9                     I am a developer by profession       No
# 9              10                     I am a developer by profession      Yes
# 10             11                     I am a developer by profession      Yes
# ...

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 6                              I am a developer by profession       No   NaN
# 7                              I am a developer by profession      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 9                              I am a developer by profession       No  30.0
# 10                             I am a developer by profession      Yes  22.0
# 11                             I am a developer by profession      Yes  23.0
# ...

# %%
filt = (df['CurrencySymbol'] == 'EUR')

# %%
df[filt]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 6                              I am a developer by profession       No   NaN
# 12                             I am a developer by profession       No  49.0
# 13          I am not primarily a developer, but I write co...      Yes  53.0
# 20                             I am a developer by profession      Yes  40.0
# 23                             I am a developer by profession      Yes  27.0
# 24                             I am a developer by profession      Yes  45.0
# 25                             I am a developer by profession       No   NaN
# 33                             I am a developer by profession      Yes  39.0
# 37                             I am a developer by profession      Yes  19.0
# 38                             I am a developer by profession       No  35.0
# ...

# %%
df.loc[~filt, 'Age'] #not in a filter

# %%
high_salary = df['ConvertedComp'] > 75000

# %%
df.loc[high_salary, 'Age']
# Out:
# Respondent
# 8        36.0
# 16       45.0
# 17       25.0
# 18       32.0
# 19       24.0
# 24       45.0
# 36       34.0
# 38       35.0
# 41        NaN
# 42       32.0
# 43        NaN
# 48       38.0
# 51        NaN
# 52       28.0
# 54       44.0
# 57       44.0
# 64       34.0
# 65       34.0
# 67       35.0
# 69       25.0
# 74       34.0
# 80       32.0
# 82       48.0
# 86       26.0
# 89       28.0
# 97       30.0
# 99       30.0
# 100      42.0
# 107      29.0
# 110      45.0
#          ...
# 65027     NaN
# 65053     NaN
# 65105     NaN
# 65170     NaN
# 65194     NaN
# 65199     NaN
# 65254     NaN
# 65278     NaN
# 65306     NaN
# 65341     NaN
# 65354     NaN
# 65375     NaN
# 65381     NaN
# 65410     NaN
# 65456     NaN
# 65461     NaN
# 65468     NaN
# 65476     NaN
# 65477     NaN
# 65502     NaN
# 65523     NaN
# 65527     NaN
# 65528     NaN
# 65554     NaN
# 65571     NaN
# 65586     NaN
# 65589     NaN
# 65602     NaN
# 65604     NaN
# 65617     NaN
# ...

# %%
Countries = ['India', 'United States', 'United Kingdom', 'Germany', 'Canada']

# %%
filt = df['Country'].isin(Countries)

# %%
df.loc[filt,'Country'].value_counts()
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
# Name: Country, dtype: int64

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
#updating columns

# %%
people = {
    "first" : ['Corey', 'Jane', 'John'],
    "last" : [' anderson', 'Mary', 'legend'],
    "email" : ['coreyand@gmail.com', 'maryjane@gmail.com', 'johnlegend@gmail.com']
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first       last                 email
# 0  Corey   anderson    coreyand@gmail.com
# 1   Jane       Mary    maryjane@gmail.com
# 2   John     legend  johnlegend@gmail.com

# %%
df = df.set_index('first')

# %%
df
# Out:
#             last                 email
# first
# Corey   anderson    coreyand@gmail.com
# Jane        Mary    maryjane@gmail.com
# John      legend  johnlegend@gmail.com

# %%
df = df.reset_index()

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.columns = ['first_name', 'last_name', 'email']

# %%
df.columns = [x.lower() for x in df.columns]

# %%
df
# Out:
#   FIRST_NAME  LAST_NAME                 EMAIL
# 0      Corey   anderson    coreyand@gmail.com
# 1       Jane       Mary    maryjane@gmail.com
# 2       John     legend  johnlegend@gmail.com

# %%
df.EMAIL
# Out:
# 0      coreyand@gmail.com
# 1      maryjane@gmail.com
# 2    johnlegend@gmail.com
# Name: EMAIL, dtype: object

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df
# Out:
#   first_name  last_name                 email
# 0      Corey   anderson    coreyand@gmail.com
# 1       Jane       Mary    maryjane@gmail.com
# 2       John     legend  johnlegend@gmail.com

# %%
df.rename(columns = {'first_name': 'first', 'last_name': 'last'}, inplace=True)

# %%
df
# Out:
#    first       last                 email
# 0  Corey   anderson    coreyand@gmail.com
# 1   Jane       Mary    maryjane@gmail.com
# 2   John     legend  johnlegend@gmail.com

# %%
df.loc[2]
# Out:
# first                    John
# last                   legend
# email    johnlegend@gmail.com
# Name: 2, dtype: object

# %%
df.loc[0] = ['john', 'smith', 'johnsmith@gmail.com']

# %%
df
# Out:
#   first    last                 email
# 0  john   smith   johnsmith@gmail.com
# 1  Jane    Mary    maryjane@gmail.com
# 2  John  legend  johnlegend@gmail.com

# %%
df.loc[2, ['last', 'email']] = ['Doe', 'johndoe@email.com']
#df.atloc[2, ['last', 'email']] = ['Doe', 'johndoe@email.com'] #Same

# %%
filt = (df['email'] == 'johndoe@email.com')

# %%
df.loc[filt, 'last'] = "smith"

# %%
filt = (df['last'] == 'smith')

# %%
df[filt]
# Out:
#   first   last                email
# 0  john  smith  johnsmith@gmail.com
# 2  John  smith    johndoe@email.com

# %%
df['email'] = df['email'].str.upper()

# %%
df
# Out:
#   first   last                email
# 0  john  smith  JOHNSMITH@GMAIL.COM
# 1  Jane   Mary   MARYJANE@GMAIL.COM
# 2  John  smith    JOHNDOE@EMAIL.COM

# %%
def update_email(email):
    return email[::-1]

# %%
df['email'].apply(update_email)
# Out:
# 0    MOC.LIAMG@HTIMSNHOJ
# 1     MOC.LIAMG@ENAJYRAM
# 2      MOC.LIAME@EODNHOJ
# Name: email, dtype: object

# %%
df['email'].apply(len)
# Out:
# 0    19
# 1    18
# 2    17
# Name: email, dtype: int64

# %%
df.apply(lambda x : len(x[2]))
# Out:
# first     4
# last      5
# email    17
# dtype: int64

# %%
df.apply(pd.Series.max)
# Out:
# first                  john
# last                  smith
# email    MARYJANE@GMAIL.COM
# dtype: object

# %%
df.apply(lambda x: x.min())
# Out:
# first                 Jane
# last                  Mary
# email    JOHNDOE@EMAIL.COM
# dtype: object

# %%
df.applymap(str.lower)
# Out:
#   first   last                email
# 0  john  smith  johnsmith@gmail.com
# 1  jane   mary   maryjane@gmail.com
# 2  john  smith    johndoe@email.com

# %%
df['first'] = df['first'].replace({'john': 'chris', 'Jane': 'Mary'})

# %%
df
# Out:
#    first   last                email
# 0  chris  smith  JOHNSMITH@GMAIL.COM
# 1   Mary   Mary   MARYJANE@GMAIL.COM
# 2   John  smith    JOHNDOE@EMAIL.COM

# %%
df1.rename(columns = {'ConvertedComp' : 'SalaryUSD'}, inplace = True)

# %%
df['Address'] = {'Houston', 'Austin', 'New york'}

# %%
df
# Out:
#    first   last                email   Address
# 0  chris  smith  JOHNSMITH@GMAIL.COM   Houston
# 1   Mary   Mary   MARYJANE@GMAIL.COM    Austin
# 2   John  smith    JOHNDOE@EMAIL.COM  New york

# %%
df['first'] + ' ' + df['last']
# Out:
# 0    chris smith
# 1      Mary Mary
# 2     John smith
# dtype: object

# %%
df['full_name'] = df['first'] +' '+ df['last']

# %%
df
# Out:
#    first       last                 email        full_name
# 0  Corey   anderson    coreyand@gmail.com  Corey  anderson
# 1   Jane       Mary    maryjane@gmail.com        Jane Mary
# 2   John     legend  johnlegend@gmail.com      John legend

# %%
df.drop(columns = ['first', 'last'], inplace = True)

# %%
df
# Out:
#    first       last                 email        full_name
# 0  Corey   anderson    coreyand@gmail.com  Corey  anderson
# 1   Jane       Mary    maryjane@gmail.com        Jane Mary
# 2   John     legend  johnlegend@gmail.com      John legend

# %%
df['full_name'].str.split(' ', expand = True)
# Out:
#        0       1         2
# 0  Corey          anderson
# 1   Jane    Mary      None
# 2   John  legend      None

# %%
df.append({'first' : 'Tony'}, ignore_index =True)
# Out:
#    first       last                 email        full_name
# 0  Corey   anderson    coreyand@gmail.com  Corey  anderson
# 1   Jane       Mary    maryjane@gmail.com        Jane Mary
# 2   John     legend  johnlegend@gmail.com      John legend
# 3   Tony        NaN                   NaN              NaN

# %%
new = df['first'] == 'Tony'

# %%
country_grp = df1.groupby('Country')

# %%
country_grp.get_group('India')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 6               7                     I am a developer by profession      Yes
# 21             22                     I am a developer by profession      Yes
# 57             58                     I am a developer by profession      Yes
# 62             63             I am a student who is learning to code      Yes
# 147           149                     I am a developer by profession      Yes
# 175           177                     I am a developer by profession      Yes
# 225           227                     I am a developer by profession      Yes
# 230           232             I am a student who is learning to code       No
# 232           234                     I am a developer by profession      Yes
# 266           268                     I am a developer by profession      Yes
# 272           274                     I am a developer by profession      Yes
# ...

# %%
country_grp['Sexuality'].value_counts(normalize=True).loc['India']
# Out:
# Sexuality
# Straight / Heterosexual                                  0.947742
# Bisexual                                                 0.040704
# Bisexual;Straight / Heterosexual                         0.003151
# Gay or Lesbian                                           0.002626
# Queer                                                    0.002363
# Bisexual;Gay or Lesbian;Straight / Heterosexual;Queer    0.000788
# Bisexual;Queer                                           0.000788
# Gay or Lesbian;Straight / Heterosexual                   0.000788
# Bisexual;Gay or Lesbian;Straight / Heterosexual          0.000263
# Bisexual;Straight / Heterosexual;Queer                   0.000263
# Gay or Lesbian;Queer                                     0.000263
# Straight / Heterosexual;Queer                            0.000263
# Name: Sexuality, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['India']
# Out:
# 10056.0

# %%
country_grp['ConvertedComp'].agg(['median', 'mean'])
# Out:
#                                              median           mean
# Country
# Afghanistan                                 15163.5  148290.125000
# Albania                                     15900.0   25611.000000
# Algeria                                      9432.0   10362.812500
# Andorra                                     88640.0   88640.000000
# Angola                                       5292.0    5292.000000
# Antigua and Barbuda                             NaN            NaN
# Argentina                                   17520.0   29010.033473
# Armenia                                     21066.0   30421.285714
# Australia                                   76831.0  146165.814767
# Austria                                     51888.0   83077.661342
# Azerbaijan                                  11988.0   14909.142857
# Bahamas                                     86706.0   86706.000000
# Bahrain                                     40196.0   39592.000000
# ...
